# %% [markdown]
# <h1 style='color:red' align='center'>Student Score Prediction</h1>

# %% [markdown]
# <h3 align='center'><b>Using Simple Linear Regression</b></h3>

# %%
#Step 1 : Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#Step 2 : Loading the dataset
student_df = pd.read_csv('student_scores.csv')
student_df.head(10)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %%
#Step 3 : Data Preperation
X= student_df.iloc[:,:-1].values
y= student_df.iloc[:,1].values

# %%
#Step 4 : Splitting the dataset
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
#Step 5 : Model Creation
model = LinearRegression()

# %%
#Step 6 : Model Training
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Step 7 : Predict with Model
print(model.predict([[3.4]]))

print(model.predict(X_test))
# Out:
# [35.71439208]
# [16.88414476 33.73226078 75.357018   26.79480124 60.49103328]

# %%
#Data Visualization
plt.title('Hours vs Percentage')
plt.xlabel("Hours Studied")
plt.ylabel("Percentage Score")
plt.scatter(X,
           y,
           color = 'red',
           marker = '*')
plt.plot(X, model.predict(X),color='blue')
plt.show()
